# %% [markdown]
# # In Depth: k-Means Clustering

# %% [markdown]
# - Clustering algorithms search for an optimal division or discrete labeling of groups of points.
# - Many clustering algorithms are available; perhaps the simplest to understand is *k-means clustering*, which is implemented in ``sklearn.cluster.KMeans``.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np

# %% [markdown]
# ### Introducing k-Means

# %% [markdown]
# - *k*-means searches for a pre-determined number of clusters within an unlabeled dataset. It accomplishes this with some simple assumptions:
#
#     - The "cluster center" is the arithmetic mean of all the points belonging to the cluster.
#     - Each point is closer to its own cluster center than to other cluster centers.
#
#
# - Build a two-dimensional dataset containing four distinct blobs. K-Means is unsupervised, so l leave the labels out of the data.

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %% [markdown]
# - Run the k-means fit & predict methods.

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %% [markdown]
# - Plot the clusters. Also plot the cluster centers as determined by *k*-means.

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# - How did k-means find these clusters so quickly? The number of possible combinations of cluster assignments is exponential in the number of data points—an exhaustive search would be very, very costly. Fortunately, an exhaustive search is not necessary. A typical approach to *k*-means involves an intuitive iterative approach known as *expectation–maximization*.

# %% [markdown]
# ###  Expectation–Maximization

# %% [markdown]
# - Expectation–maximization (E–M) is a powerful algorithm that consists of the following procedure:
#
# 1. Guess some cluster centers
# 2. Repeat until converged
#    1. *E-Step*: assign points to the nearest cluster center
#    2. *M-Step*: set the cluster centers to the mean
#
# - The "Expectation step" is named because it involves updating our expectation of which cluster each point belongs to. The "Maximization step" involves maximizing some fitness function that defines the location of the cluster centers—in this case, that maximization is accomplished by taking a simple mean of the data in each cluster.
#
# - The literature about this algorithm is vast, but can be summarized as follows: under typical circumstances, each repetition of the E-step and M-step will always result in a better estimate of the cluster characteristics.
#
# - We can visualize the algorithm as shown. In this case the clusters converge in just three iterations.

# %% [markdown]
# ![(run code in Appendix to generate image)](figures/05.11-expectation-maximization.png)

# %% [markdown]
# - *k*-Means is simple enough that we can write it in a few lines of code.

# %%
from sklearn.metrics import pairwise_distances_argmin

def find_clusters(X, n_clusters, rseed=2):
    # 1. Randomly choose clusters
    rng = np.random.RandomState(rseed)
    i = rng.permutation(X.shape[0])[:n_clusters]
    centers = X[i]
    
    while True:
        # 2a. Assign labels based on closest center
        labels = pairwise_distances_argmin(X, centers)
        
        # 2b. Find new centers from means of points
        new_centers = np.array([X[labels == i].mean(0)
                                for i in range(n_clusters)])
        
        # 2c. Check for convergence
        if np.all(centers == new_centers):
            break
        centers = new_centers
    
    return centers, labels

centers, labels = find_clusters(X, 4)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');

# %% [markdown]
# - Most implementations do a bit more under the hood, but the preceding function gives the gist of the expectation–maximization approach.

# %% [markdown]
# ### Caveats of expectation–maximization
#
# There are a few issues to be aware of when using the expectation–maximization algorithm.

# %% [markdown]
# #### The globally optimal result may not be achieved
#
# - Although the E–M procedure is guaranteed to improve the result in each step, there is no assurance that it will lead to a *global* best solution. For example, if we use a different random seed in our simple procedure, the particular starting guesses lead to poor results:

# %%
centers, labels = find_clusters(X, 4, rseed=0)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');

# %% [markdown]
# - Here the E–M approach has converged, but not to a globally optimal configuration. It is therefore common for the algorithm to be run for multiple starting guesses, as indeed Scikit-Learn does by default (set by the ``n_init`` parameter, which defaults to 10).

# %% [markdown]
# #### The number of clusters must be selected beforehand
# - *k*-means cannot learn the number of clusters from the data. For example, if we ask the algorithm to identify six clusters, it will happily proceed and find the best six clusters:

# %%
labels = KMeans(6, random_state=0).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');

# %% [markdown]
# - Whether the result is meaningful is a question that is difficult to answer definitively; one approach that is rather intuitive, but that we won't discuss further here, is called [silhouette analysis](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html).
#
# - One can use a more complicated clustering algorithm which has a better quantitative measure of the fitness per number of clusters (e.g., Gaussian mixture models; see [In Depth: Gaussian Mixture Models](05.12-Gaussian-Mixtures.ipynb)) or which *can* choose a suitable number of clusters (e.g., DBSCAN, mean-shift, or affinity propagation, all available in the ``sklearn.cluster`` submodule)

# %% [markdown]
# #### k-means is limited to linear cluster boundaries
# - The fundamental model assumptions of *k*-means (points will be closer to their own cluster center than to others) means that the algorithm will often be ineffective if the clusters have complicated geometries.
#
# - Consider this example along with the cluster labels found by the typical *k*-means approach:

# %%
from sklearn.datasets import make_moons
X, y = make_moons(200, noise=.05, random_state=0)

# %%
labels = KMeans(2, random_state=0).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');

# %% [markdown]
# - This is similar to the SVM example [In-Depth: Support Vector Machines](05.07-Support-Vector-Machines.ipynb), where we used a kernel transformation to project the data into a higher dimension where a linear separation is possible.
# - Consider using the same trick to allow *k*-means to discover non-linear boundaries. One version of this kernelized *k*-means is a ``SpectralClustering`` estimator. It uses the graph of nearest neighbors to compute a higher-dimensional representation of the data, and then assigns labels using a *k*-means algorithm:

# %%
from sklearn.cluster import SpectralClustering
model = SpectralClustering(n_clusters=2, affinity='nearest_neighbors',
                           assign_labels='kmeans')
labels = model.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');
# Out:
# /home/bjpcjp/anaconda3/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:234: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %% [markdown]
# - With this kernel transform approach, the kernelized *k*-means is able to find more complicated nonlinear boundaries between clusters.

# %% [markdown]
# #### k-means can be slow for large numbers of samples
# - Each iteration of *k*-means must access every point in the dataset. The algorithm can be relatively slow as the number of samples grows.
# - The use-all-data requirement can be relaxed. For example, you might use a subset of the data to update the cluster centers at each step. This is the idea behind batch-based *k*-means algorithms. One example of this is ``sklearn.cluster.MiniBatchKMeans``.

# %% [markdown]
# ### Example 1: k-means on digits
#
# - Attempt to use *k*-means to try to identify similar examples from the digits dataset *without using the original labels*; this might be similar to a first step in extracting meaning from a new dataset about which you don't have any *a priori* label information.
#
# - Start by loading the digits and then finding the ``KMeans`` clusters. Recall the digits consist of 1,797 samples with 64 features (each is the brightness of one pixel in an 8×8 image).

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %% [markdown]
# - run k-means.

# %%
kmeans = KMeans(n_clusters=10, random_state=0)
clusters = kmeans.fit_predict(digits.data)
kmeans.cluster_centers_.shape
# Out:
# (10, 64)

# %% [markdown]
# - We've got 10 clusters in 64 dimensions. The cluster centers are 64-dimensional points, and can themselves be interpreted as the "typical" digit within the cluster. Let's see what these cluster centers look like.

# %%
fig, ax = plt.subplots(2, 5, figsize=(8, 3))
centers = kmeans.cluster_centers_.reshape(10, 8, 8)
for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='nearest', cmap=plt.cm.binary)

# %% [markdown]
# - We see that *even without labels*, ``KMeans`` can to find clusters whose centers are recognizable digits, with perhaps the exception of 1 and 8.
# - Because *k*-means knows nothing about the identity of the cluster, the 0–9 labels may be permuted. We can fix this by matching each learned cluster label with the true labels found in them:

# %%
from scipy.stats import mode

labels = np.zeros_like(clusters)
for i in range(10):
    mask = (clusters == i)
    labels[mask] = mode(digits.target[mask])[0]

# %% [markdown]
# - Check how accurate our unsupervised clustering was in finding similar digits within the data:

# %%
from sklearn.metrics import accuracy_score
accuracy_score(digits.target, labels)
# Out:
# 0.79354479688369506

# %% [markdown]
# - Check the confusion matrix too:

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(digits.target, labels)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=digits.target_names,
            yticklabels=digits.target_names)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# - As expected, the main point of confusion is between the eights and ones. But it still shows that with *k*-means we can build a digit classifier *without reference to any known labels*!
#
# - Use the t-distributed stochastic neighbor embedding (t-SNE) algorithm to pre-process the data before performing *k*-means. t-SNE is a nonlinear embedding algorithm that is particularly adept at preserving points within clusters.

# %%
from sklearn.manifold import TSNE

# Project the data: this step will take several seconds
tsne = TSNE(n_components=2, init='random', random_state=0)
digits_proj = tsne.fit_transform(digits.data)

# Compute the clusters
kmeans = KMeans(n_clusters=10, random_state=0)
clusters = kmeans.fit_predict(digits_proj)

# Permute the labels
labels = np.zeros_like(clusters)
for i in range(10):
    mask = (clusters == i)
    labels[mask] = mode(digits.target[mask])[0]

# Compute the accuracy
accuracy_score(digits.target, labels)
# Out:
# 0.9326655537006121

# %% [markdown]
# - That's >93% classification accuracy *without using the labels*.

# %% [markdown]
# ### Example: *k*-means for color compression
#
# - One interesting application of clustering is color compression within images. For example, imagine you have an image with millions of colors. In most images, a large number of the colors will be unused, and many of the pixels in the image will have similar or even identical colors.
#
# - Consider the image shown in the following figure, which is from the Scikit-Learn ``datasets`` module (for this to work, you'll have to have the ``pillow`` Python package installed).

# %%
# Note: this requires the ``pillow`` package to be installed
from sklearn.datasets import load_sample_image
china = load_sample_image("china.jpg")
ax = plt.axes(xticks=[], yticks=[])
ax.imshow(china);

# %% [markdown]
# - The image is stored in a three-dimensional array of size ``(height, width, RGB)``, containing red/blue/green contributions as integers from 0 to 255.

# %%
china.shape
# Out:
# (427, 640, 3)

# %% [markdown]
# - We can view this set of pixels is as a cloud of points in a three-dimensional color space. Reshape the data to ``[n_samples x n_features]``, and rescale the colors so that they lie between 0 and 1.

# %%
data = china / 255.0 # use 0...1 scale
data = data.reshape(427 * 640, 3)
data.shape
# Out:
# (273280, 3)

# %% [markdown]
# - View the pixels in this color space. Use a subset of 10,000 pixels for efficiency.

# %%
def plot_pixels(data, title, colors=None, N=10000):
    if colors is None:
        colors = data
    
    # choose a random subset
    rng = np.random.RandomState(0)
    i = rng.permutation(data.shape[0])[:N]
    colors = colors[i]
    R, G, B = data[i].T
    
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    ax[0].scatter(R, G, color=colors, marker='.')
    ax[0].set(xlabel='Red', ylabel='Green', xlim=(0, 1), ylim=(0, 1))

    ax[1].scatter(R, B, color=colors, marker='.')
    ax[1].set(xlabel='Red', ylabel='Blue', xlim=(0, 1), ylim=(0, 1))

    fig.suptitle(title, size=20);

# %%
plot_pixels(data, title='Input color space: 16 million possible colors')

# %% [markdown]
# - Now let's reduce these 16 million colors to 16 colors, using a *k*-means clustering across the pixel space.
# - Because we are dealing with a very large dataset, use the mini batch *k*-means, which operates on subsets of the data to compute the result much more quickly.

# %%
import warnings; warnings.simplefilter('ignore')  # Fix NumPy issues.

from sklearn.cluster import MiniBatchKMeans
kmeans = MiniBatchKMeans(16)
kmeans.fit(data)
new_colors = kmeans.cluster_centers_[kmeans.predict(data)]

plot_pixels(data, colors=new_colors,
            title="Reduced color space: 16 colors")

# %% [markdown]
# - The result is a re-coloring of the original pixels, where each pixel is assigned the color of its closest cluster center. Plotting these new colors in the image space rather than the pixel space shows us the effect of this:

# %%
china_recolored = new_colors.reshape(china.shape)

fig, ax = plt.subplots(1, 2, figsize=(16, 6),
                       subplot_kw=dict(xticks=[], yticks=[]))
fig.subplots_adjust(wspace=0.05)
ax[0].imshow(china)
ax[0].set_title('Original Image', size=16)
ax[1].imshow(china_recolored)
ax[1].set_title('16-color Image', size=16);

# %% [markdown]
# - Some detail is lost in the rightmost panel, but the image is still recognizable. The image on the right achieves a compression factor of around 1 million! While this is an interesting application of *k*-means, there are better way to compress information in images. But the example shows the power of thinking outside of the box with unsupervised methods like *k*-means.
